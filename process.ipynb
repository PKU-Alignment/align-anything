# %%
from datasets import load_dataset
from pprint import pprint

path = "/aifs4su/yaodong/datasets/RLAIF-V-train"
data = load_dataset(path)
pprint(data)
pprint(data['train'][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['ds_name', 'image', 'question', 'chosen', 'rejected', 'origin_dataset', 'origin_split', 'idx', 'image_path'],
#         num_rows: 20000
#     })
# })
# {'chosen': 'In the image, there are bananas visible in the scene. Bananas are '
#            "typically yellow or green when unripe, so it's likely that the "
#            'bananas are in a ripe state. As for red fruits, there is no red '
#            'banana or peach present in the image. The primary focus of the '
#            'image is an orangutan holding and eating bananas in a forest '
#            'setting.',
#  'ds_name': 'RLAIF-V',
#  'idx': 'OmniLMM-12B_OmniLMM-12B_2942',
#  'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=333x500 at 0x1554032CD490>,
#  'image_path': 'gqa/images/2382745.jpg',
#  'origin_dataset': 'GQA',
#  'origin_split': '{"model": "OmniLMM-12B", "feedback_model": "OmniLMM-12B", '
#                  '"type": "question_answering"}',
#  'question': 'Is there red banana or peach?',
#  'rejected': 'Based on the image, the bananas that the orangutan is holding '
#              'appear to be yellow, which is a typical color for ripe bananas. '
#              'There is no red banana or peach visible in the image.'}

# %%
from datasets import load_dataset
from pprint import pprint

path = "/aifs4su/yaodong/datasets/ClothoAQA"
data = load_dataset(path)
pprint(data)
pprint(data['train'][:20])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file_name', 'QuestionText', 'answer', 'confidence'],
#         num_rows: 21132
#     })
#     validation: Dataset({
#         features: ['file_name', 'QuestionText', 'answer', 'confidence'],
#         num_rows: 6192
#     })
#     test: Dataset({
#         features: ['file_name', 'QuestionText', 'answer', 'confidence'],
#         num_rows: 8514
#     })
# })
# {'QuestionText': ['Are there more than one bird squawking?',
#                   'Are there more than one bird squawking?',
#                   'Are there more than one bird squawking?',
#                   'Are there people having a conversation?',
#                   'Are there people having a conversation?',
#                   'Are there people having a conversation?',
#                   'Are these animals outside?',
#                   'Are these animals outside?',
#                   'Are these animals outside?',
#                   'How many birds are squawking?',
#                   'How many birds are squawking?',
#                   'How many birds are squawking?',
#                   'How many cars honk their horn?',
#                   'How many cars honk their horn?',
#                   'How many cars honk their horn?',
#                   'Is there only one bird sqauwking?',
#                   'Is there only one bird sqauwking?',
#                   'Is there only one bird sqauwking?',
#                   'How many birds are making noise?',
#                   'How many birds are making noise?'],
#  'answer': ['yes',
#             'yes',
#             'yes',
#             'no',
#             'no',
#             'no',
#             'no',
#             'yes',
#             'yes',
#             'three',
#             'three',
#             'two',
#             'zero',
#             'one',
#             'one',
#             'no',
#             'no',
#             'no',
#             'two',
#             'two'],
#  'confidence': ['yes',
#                 'yes',
#                 'yes',
#                 'yes',
#                 'yes',
#                 'yes',
#                 'maybe',
#                 'yes',
#                 'yes',
#                 'Maybe',
#                 'Maybe',
#                 'Maybe',
#                 'Yes',
#                 'Yes',
#                 'Yes',
#                 'yes',
#                 'yes',
#                 'yes',
#                 'Maybe',
#                 'Maybe'],
#  'file_name': ['AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                'AmbianceBackyard_Quiet_bip.wav',
#                '20110121_cranes.wind.wav',
#                '20110121_cranes.wind.wav']}

# %%
from datasets import load_dataset
from pprint import pprint
from collections import Counter

path = "/aifs4su/yaodong/datasets/ClothoAQA"
data = load_dataset(path)
pprint(data)
count = Counter(data['train']['answer'])
pprint(count)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file_name', 'QuestionText', 'answer', 'confidence'],
#         num_rows: 21132
#     })
#     validation: Dataset({
#         features: ['file_name', 'QuestionText', 'answer', 'confidence'],
#         num_rows: 6192
#     })
#     test: Dataset({
#         features: ['file_name', 'QuestionText', 'answer', 'confidence'],
#         num_rows: 8514
#     })
# })
# Counter({'yes': 8049,
#          'no': 6039,
#          'two': 285,
#          'water': 280,
#          'one': 239,
#          'bird': 206,
#          'three': 188,
#          'birds': 131,
#          'rain': 129,
#          'four': 105,
#          'five': 100,
#          'train': 95,
#          'car': 88,
#          'walking': 87,
#          'talking': 86,
#          'metal': 84,
#          'chirping': 76,
#          'dog': 68,
#          'six': 64,
#          'door': 62,
#          'wood': 59,
#          'engine': 56,
#          'wind': 55,
#          'zero': 48,
#          'truck': 48,
#          'seven': 47,
#          'eight': 47,
#          'bell': 45,
#          'machine': 44,
#          'rainy': 44,
#          'ten': 42,
#          'twenty': 40,
#          'none': 40,
#          'thunder': 40,
#          'raining': 39,
#          'paper': 34,
#          'airplane': 33,
#          'static': 33,
#          'once': 33,
#          'cricket': 32,
#          'female': 31,
#          'running': 31,
#          'waves': 29,
#          'radio': 28,
#          'driving': 28,
#          'male': 28,
#          'glass': 27,
#          'thirty': 27,
#          'siren': 26,
#          'nine': 25,
#          'outside': 25,
#          'many': 25,
#          'gravel': 25,
#          'flowing': 24,
#          'drum': 23,
#          'bus': 23,
#          'singing': 22,
#          'motorcycle': 22,
#          'twelve': 22,
#          'cat': 21,
#          'liquid': 21,
#          'leaves': 21,
#          'fan': 21,
#          'snow': 21,
#          'people': 20,
#          'plastic': 20,
#          'barking': 20,
#          'fast': 19,
#          'human': 19,
#          'dripping': 19,
#          'sixteen': 19,
#          'fifteen': 19,
#          'saw': 19,
#          'eleven': 18,
#          'moving': 18,
#          'church': 18,
#          'hammer': 18,
#          'windy': 18,
#          'piano': 17,
#          'horn': 16,
#          'traffic': 16,
#          'motor': 16,
#          'bike': 16,
#          'vehicle': 16,
#          'nothing': 16,
#          'cars': 16,
#          'thirteen': 16,
#          'music': 15,
#          'air': 15,
#          'ice': 15,
#          'sound': 15,
#          'plane': 14,
#          'toilet': 14,
#          'end': 14,
#          'ocean': 14,
#          'faucet': 13,
#          'fifty': 13,
#          'high': 13,
#          'crickets': 13,
#          'road': 13,
#          'flying': 13,
#          'wet': 13,
#          'person': 12,
#          'unknown': 12,
#          'duck': 12,
#          'twice': 12,
#          'writing': 12,
#          'clock': 12,
#          'stops': 12,
#          'nineteen': 11,
#          'steel': 11,
#          'tap': 11,
#          'fire': 11,
#          'shoes': 11,
#          'frog': 11,
#          'very': 11,
#          'forty': 11,
#          'cow': 11,
#          'floor': 10,
#          'pouring': 10,
#          'crow': 10,
#          'eating': 10,
#          'waterfall': 10,
#          'fourteen': 10,
#          'bee': 10,
#          'splashing': 10,
#          'beginning': 10,
#          'seventeen': 10,
#          'subway': 10,
#          'falling': 10,
#          'loud': 10,
#          'sink': 10,
#          'table': 10,
#          'hand': 10,
#          'chirp': 10,
#          'grass': 10,
#          'lawnmower': 10,
#          'microwave': 10,
#          'rooster': 9,
#          'guitar': 9,
#          'fly': 9,
#          'ambulance': 9,
#          'forest': 9,
#          'scraping': 9,
#          'breathing': 9,
#          'kitchen': 9,
#          'dropping': 9,
#          'tapping': 9,
#          'horse': 9,
#          'children': 9,
#          'alarm': 9,
#          'chair': 9,
#          'bathroom': 9,
#          'book': 9,
#          'down': 9,
#          'keys': 9,
#          'horror': 9,
#          'clapping': 8,
#          'bucket': 8,
#          'stairs': 8,
#          'dryer': 8,
#          'interested': 8,
#          'man': 8,
#          'pig': 8,
#          'keyboard': 8,
#          'hitting': 8,
#          'monkey': 8,
#          'drill': 8,
#          'knocking': 8,
#          'speaking': 8,
#          'storm': 8,
#          'stormy': 8,
#          'mouth': 8,
#          'typing': 8,
#          'shower': 8,
#          'pavement': 8,
#          'boat': 8,
#          'eighteen': 8,
#          'bells': 8,
#          'squeaking': 8,
#          'chicken': 7,
#          'synthesizer': 7,
#          'dishes': 7,
#          'opening': 7,
#          'woman': 7,
#          'speaker': 7,
#          'cup': 7,
#          'drums': 7,
#          'washer': 7,
#          'mower': 7,
#          'knife': 7,
#          'draining': 7,
#          'boiling': 7,
#          'jackhammer': 7,
#          'twentyfive': 7,
#          'oil': 7,
#          'pulling': 7,
#          'stream': 7,
#          'cutter': 7,
#          'bottle': 7,
#          'low': 7,
#          'screeching': 7,
#          'feet': 7,
#          'flute': 7,
#          'street': 7,
#          'start': 7,
#          'rainfall': 7,
#          'tracks': 7,
#          'factory': 6,
#          'white': 6,
#          'tractor': 6,
#          'roof': 6,
#          'tin': 6,
#          'ringing': 6,
#          'twentysix': 6,
#          'close': 6,
#          'buzzing': 6,
#          'welding': 6,
#          'useful': 6,
#          'shooting': 6,
#          'accelerating': 6,
#          'thunderstorm': 6,
#          'cooking': 6,
#          'typewriter': 6,
#          'rocks': 6,
#          'gate': 6,
#          'middle': 6,
#          'airport': 6,
#          'whistle': 6,
#          'whistling': 6,
#          'toy': 6,
#          'playing': 6,
#          'child': 6,
#          'construction': 6,
#          'washing': 6,
#          'chainsaw': 6,
#          'insects': 6,
#          'ground': 6,
#          'stop': 6,
#          'small': 6,
#          'restaurant': 6,
#          'beeping': 6,
#          'laughing': 6,
#          'first': 6,
#          'cheering': 6,
#          'crying': 6,
#          'chimes': 6,
#          'steady': 6,
#          'tennis': 6,
#          'drive': 6,
#          'can': 6,
#          'reading': 6,
#          'river': 5,
#          'trees': 5,
#          'window': 5,
#          'aeroplane': 5,
#          'stapler': 5,
#          'printing': 5,
#          'crinkling': 5,
#          'slowly': 5,
#          'iron': 5,
#          'popcorn': 5,
#          'insect': 5,
#          'jar': 5,
#          'sheep': 5,
#          'working': 5,
#          'cleaning': 5,
#          'chopping': 5,
#          'ball': 5,
#          'helicopter': 5,
#          'good': 5,
#          'squeak': 5,
#          'beach': 5,
#          'night': 5,
#          'hard': 5,
#          'box': 5,
#          'coin': 5,
#          'cough': 5,
#          'cutting': 5,
#          'rock': 5,
#          'twentyfour': 5,
#          'key': 5,
#          'park': 5,
#          'medium': 5,
#          'shouting': 5,
#          'owl': 5,
#          'bathing': 5,
#          'rod': 5,
#          'organ': 5,
#          'xylophone': 5,
#          'announcement': 5,
#          'pilot': 5,
#          'umbrella': 5,
#          'second': 5,
#          'lock': 5,
#          'electricity': 5,
#          'blowing': 5,
#          'tires': 5,
#          'office': 5,
#          'pipe': 5,
#          'chatting': 5,
#          'never': 5,
#          'lion': 5,
#          'drain': 5,
#          'coffee': 5,
#          'cock': 5,
#          'twentyeight': 5,
#          'coins': 5,
#          'exhaust': 5,
#          'brakes': 5,
#          'stone': 5,
#          'soda': 5,
#          'tape': 5,
#          'board': 4,
#          'hen': 4,
#          'men': 4,
#          'highway': 4,
#          'ducks': 4,
#          'summer': 4,
#          'away': 4,
#          'television': 4,
#          'audience': 4,
#          'brush': 4,
#          'changing': 4,
#          'wrench': 4,
#          'vehicles': 4,
#          'loudspeaker': 4,
#          'fades': 4,
#          'wheel': 4,
#          'pebbles': 4,
#          'steps': 4,
#          'boots': 4,
#          'station': 4,
#          'morning': 4,
#          'fabric': 4,
#          'papers': 4,
#          'grinder': 4,
#          'twentyone': 4,
#          'concrete': 4,
#          'electronic': 4,
#          'heavy': 4,
#          'spinner': 4,
#          'emergency': 4,
#          'slow': 4,
#          'outdoors': 4,
#          'shoe': 4,
#          'parrot': 4,
#          'baby': 4,
#          'normal': 4,
#          'grinding': 4,
#          'machinery': 4,
#          'railwaystation': 4,
#          'banging': 4,
#          'coffeemaker': 4,
#          'frogs': 4,
#          'feathers': 4,
#          'evening': 4,
#          'up': 4,
#          'market': 4,
#          'swimming': 4,
#          'third': 4,
#          'hiking': 4,
#          'humans': 4,
#          'bag': 4,
#          'goose': 4,
#          'whirring': 4,
#          'diesel': 4,
#          'racing': 4,
#          'footsteps': 4,
#          'clap': 4,
#          'tornado': 4,
#          'steam': 4,
#          'speed': 4,
#          'sparrow': 4,
#          'police': 4,
#          'chewing': 4,
#          'cards': 4,
#          'chips': 4,
#          'revving': 4,
#          'sawing': 4,
#          'kids': 4,
#          'happy': 3,
#          'squawking': 3,
#          'stick': 3,
#          'belt': 3,
#          'racetrack': 3,
#          'pencil': 3,
#          'twentyseven': 3,
#          'pingpong': 3,
#          'chirps': 3,
#          'elephant': 3,
#          'bubbling': 3,
#          'straw': 3,
#          'crowd': 3,
#          'broom': 3,
#          'sounds': 3,
#          'meeting': 3,
#          'tool': 3,
#          'twentytwo': 3,
#          'long': 3,
#          'stirring': 3,
#          'fourty': 3,
#          'generator': 3,
#          'sewing': 3,
#          'sander': 3,
#          'shaking': 3,
#          'always': 3,
#          'women': 3,
#          'tub': 3,
#          'thirtyfive': 3,
#          'electric': 3,
#          'pop': 3,
#          'food': 3,
#          'silverware': 3,
#          'clouds': 3,
#          'wave': 3,
#          'noise': 3,
#          'hands': 3,
#          'sniffing': 3,
#          'silent': 3,
#          'twentythree': 3,
#          'watch': 3,
#          'screaming': 3,
#          'driller': 3,
#          'teeth': 3,
#          'styrofoam': 3,
#          'sea': 3,
#          'crunching': 3,
#          'band': 3,
#          'jogging': 3,
#          'hundred': 3,
#          'fingers': 3,
#          'bang': 3,
#          'mixer': 3,
#          'refrigerator': 3,
#          'big': 3,
#          'cabinet': 3,
#          'cooker': 3,
#          'fountain': 3,
#          'adult': 3,
#          'bear': 3,
#          'gas': 3,
#          'moderately': 3,
#          'crackers': 3,
#          'playground': 3,
#          'far': 3,
#          'laugh': 3,
#          'cicada': 3,
#          'voices': 3,
#          'blender': 3,
#          'spilling': 3,
#          'starting': 3,
#          'aluminum': 3,
#          'coughing': 3,
#          'digging': 3,
#          'flight': 3,
#          'fireworks': 3,
#          'computer': 3,
#          'winter': 3,
#          'waterflow': 3,
#          'seagulls': 3,
#          'sharpening': 3,
#          'marker': 3,
#          'rinsing': 3,
#          'violin': 3,
#          'notebook': 3,
#          'pipes': 3,
#          'hammering': 3,
#          'breaking': 3,
#          'cart': 3,
#          'scribbling': 3,
#          'basketball': 3,
#          'balloon': 3,
#          'top': 3,
#          'pulsing': 3,
#          'nests': 3,
#          'bottles': 3,
#          'deep': 3,
#          'cymbal': 3,
#          'kettle': 3,
#          'several': 2,
#          'seagull': 2,
#          'prayer': 2,
#          'match': 2,
#          'geese': 2,
#          'freight': 2,
#          'announcer': 2,
#          'humming': 2,
#          'heater': 2,
#          'industrial': 2,
#          'utensils': 2,
#          'pigeon': 2,
#          'clanging': 2,
#          'house': 2,
#          'zoo': 2,
#          'wrapping': 2,
#          'locust': 2,
#          'fish': 2,
#          'crushing': 2,
#          'object': 2,
#          'rubber': 2,
#          'ship': 2,
#          'folding': 2,
#          'hay': 2,
#          'bass': 2,
#          'instrument': 2,
#          'wheelbarrow': 2,
#          'elevator': 2,
#          'gasoline': 2,
#          'eggs': 2,
#          'whir': 2,
#          'tile': 2,
#          'throwing': 2,
#          'rapidly': 2,
#          'rat': 2,
#          'twentynine': 2,
#          'signal': 2,
#          'work': 2,
#          'mat': 2,
#          'cuckoo': 2,
#          'constantly': 2,
#          'swing': 2,
#          'mike': 2,
#          'quickly': 2,
#          'more': 2,
#          'fence': 2,
#          'package': 2,
#          'dirt': 2,
#          'trumpet': 2,
#          'movement': 2,
#          'auditorium': 2,
#          'sand': 2,
#          'metals': 2,
#          'spoon': 2,
#          'crows': 2,
#          'sirens': 2,
#          'cicadas': 2,
#          'theremin': 2,
#          'lake': 2,
#          'lightening': 2,
#          'howling': 2,
#          'firetruck': 2,
#          'mouse': 2,
#          'pan': 2,
#          'passing': 2,
#          'buzz': 2,
#          'phone': 2,
#          'noises': 2,
#          'multiple': 2,
#          'golf': 2,
#          'bowl': 2,
#          'seawave': 2,
#          'soft': 2,
#          'animal': 2,
#          'louder': 2,
#          'flow': 2,
#          'raindrops': 2,
#          'party': 2,
#          'clicking': 2,
#          'ratchet': 2,
#          'pen': 2,
#          'last': 2,
#          'pullover': 2,
#          'building': 2,
#          'tree': 2,
#          'hissing': 2,
#          'branches': 2,
#          'pot': 2,
#          'race': 2,
#          'configuration': 2,
#          'ac': 2,
#          'laundry': 2,
#          'wheels': 2,
#          'triangle': 2,
#          'gong': 2,
#          'pool': 2,
#          'home': 2,
#          'constant': 2,
#          'bicycle': 2,
#          'roaring': 2,
#          'garage': 2,
#          'school': 2,
#          'drink': 2,
#          'city': 2,
#          'scream': 2,
#          'creaking': 2,
#          'hall': 2,
#          'scratching': 2,
#          'plain': 2,
#          'splash': 2,
#          'game': 2,
#          'tweet': 2,
#          'fuel': 2,
#          'crashing': 2,
#          'chime': 2,
#          'accelerates': 2,
#          'sixty': 2,
#          'growl': 2,
#          'nice': 2,
#          'tunnel': 2,
#          'mild': 2,
#          'sweeping': 2,
#          'slamming': 2,
#          'showering': 2,
#          'thirtyeight': 2,
#          'thirtyone': 2,
#          'spring': 2,
#          'hinge': 2,
#          'silence': 2,
#          'sidewalk': 2,
#          'automobiles': 2,
#          'floorboard': 2,
#          'rattling': 2,
#          'locusts': 2,
#          'seesaw': 2,
#          'jet': 2,
#          'song': 2,
#          'railroad': 2,
#          'babbling': 2,
#          'vacuum': 2,
#          'waking': 2,
#          'frying': 2,
#          'bugs': 2,
#          'rails': 2,
#          'travel': 2,
#          'sleeping': 2,
#          'light': 2,
#          'plate': 2,
#          'falls': 2,
#          'garbage': 2,
#          'shredding': 2,
#          'copier': 2,
#          'foot': 2,
#          'growling': 2,
#          'continuously': 2,
#          'lorry': 2,
#          'motorbike': 2,
#          'racecar': 2,
#          'beads': 2,
#          'shore': 2,
#          'timer': 2,
#          'dice': 2,
#          'drawing': 2,
#          'pulled': 2,
#          'snake': 2,
#          'bees': 2,
#          'clucking': 2,
#          'mixing': 2,
#          'flies': 2,
#          'utensil': 2,
#          'glasses': 2,
#          'consistent': 2,
#          'drip': 2,
#          'microphone': 2,
#          'telephone': 2,
#          'tv': 2,
#          'purring': 2,
#          'winder': 2,
#          'excitement': 1,
#          'freeway': 1,
#          'listening': 1,
#          'vibrating': 1,
#          'whispering': 1,
#          'dove': 1,
#          'chiming': 1,
#          'rapid': 1,
#          'arguing': 1,
#          'he': 1,
#          '8times': 1,
#          'rake': 1,
#          'books': 1,
#          'tarp': 1,
#          'bubblewrap': 1,
#          'whisper': 1,
#          'completion': 1,
#          'egg': 1,
#          'short': 1,
#          'rushing': 1,
#          'canvas': 1,
#          'parakeet': 1,
#          'dishwasher': 1,
#          'scooter': 1,
#          'dirtbike': 1,
#          'tools': 1,
#          'fireplace': 1,
#          'scraper': 1,
#          'tuba': 1,
#          'urinating': 1,
#          'drilling': 1,
#          'flood': 1,
#          'wd-40': 1,
#          'happiness': 1,
#          'drizzling': 1,
#          'dribbling': 1,
#          'fryingpan': 1,
#          'sizzling': 1,
#          'windchime': 1,
#          'crunch': 1,
#          'semi': 1,
#          'thirtyseven': 1,
#          'woodpecker': 1,
#          'seventythree': 1,
#          'shaker': 1,
#          'steeldrum': 1,
#          'arcade': 1,
#          'dress': 1,
#          'grains': 1,
#          'sprayer': 1,
#          'waters': 1,
#          'bad': 1,
#          'ghost': 1,
#          'creek': 1,
#          'english': 1,
#          'farm': 1,
#          'hose': 1,
#          'sixth': 1,
#          'east': 1,
#          'quiet': 1,
#          'swinging': 1,
#          'intercom': 1,
#          'airsound': 1,
#          'blue': 1,
#          'latch': 1,
#          'vacuuming': 1,
#          'sitting': 1,
#          'smooth': 1,
#          'press': 1,
#          'cut': 1,
#          'open': 1,
#          'landing': 1,
#          'store': 1,
#          'breezy': 1,
#          'tire': 1,
#          'gutters': 1,
#          'breaks': 1,
#          'hog': 1,
#          'tank': 1,
#          'buzzsaw': 1,
#          'magazine': 1,
#          'sky': 1,
#          'peeing': 1,
#          'knock': 1,
#          'winch': 1,
#          'filling': 1,
#          'brook': 1,
#          'sunny': 1,
#          'sorter': 1,
#          'chain': 1,
#          'tearing': 1,
#          'sing': 1,
#          'hail': 1,
#          'clanking': 1,
#          'mosquito': 1,
#          'rollercoaster': 1,
#          'lightning': 1,
#          'printer': 1,
#          'alot': 1,
#          'honk': 1,
#          'noisy': 1,
#          'mug': 1,
#          'closet': 1,
#          'cardboard': 1,
#          'tambourine': 1,
#          'voice': 1,
#          'semitruck': 1,
#          'cheer': 1,
#          'honking': 1,
#          'sharpener': 1,
#          'vaccum': 1,
#          'walk': 1,
#          'marbles': 1,
#          'flushing': 1,
#          'stomping': 1,
#          'batminton': 1,
#          'rabit': 1,
#          'hurricane': 1,
#          'blow': 1,
#          'roller': 1,
#          'shop': 1,
#          'thud': 1,
#          'closing': 1,
#          'hardwood': 1,
#          'cycle': 1,
#          'pour': 1,
#          'stir': 1,
#          'distortion': 1,
#          'vibration': 1,
#          'debris': 1,
#          'yelling': 1,
#          'mowing': 1,
#          'goat': 1,
#          'aquarium': 1,
#          'travelling': 1,
#          'left': 1,
#          'mud': 1,
#          'laughter': 1,
#          'radar': 1,
#          'scanner': 1,
#          'cracker': 1,
#          'crunchy': 1,
#          'crispy': 1,
#          'celery': 1,
#          'drop': 1,
#          'fall': 1,
#          'thirtyfour': 1,
#          'thirtythree': 1,
#          'marble': 1,
#          'rice': 1,
#          'screech': 1,
#          'grasshoppers': 1,
#          'tumbling': 1,
#          'steal': 1,
#          'pump': 1,
#          'storming': 1,
#          'cluck': 1,
#          'shovel': 1,
#          'teapot': 1,
#          'fighting': 1,
#          'dolphin': 1,
#          'increase': 1,
#          'classical': 1,
#          'balls': 1,
#          'manufacturing': 1,
#          'bat': 1,
#          'bridge': 1,
#          'mockingbird': 1,
#          'drumstick': 1,
#          'skateboard': 1,
#          'rainstorm': 1,
#          'crank': 1})
